# %%
import time as tm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Function to find product links
def find_link(driver):
    base_url = 'https://clickbuy.com.vn/hang-cu?page='
    all_links = []

    # Loop through pages from 1 to 11
    for page in range(1, 12):
        url = f'{base_url}{page}'
        driver.get(url)
        tm.sleep(3)  # Wait for the page to load

        # Find all <a> tags containing product links
        lst_xpath = '//div[@class="list-products"]/div/a'
        tags = driver.find_elements(By.XPATH, lst_xpath)

        # Get href attributes from each tag and add to the list
        new_tags = [tag.get_attribute('href') for tag in tags if tag.get_attribute('href')]
        all_links.extend(new_tags)
    return all_links

def save_to_csv(data, feature_names):
    df = pd.DataFrame(data, columns=feature_names)
    df.to_csv("products_Click_buy.csv", index=False, encoding='utf-8-sig')

def prepare_data(data_raw):
    data = {"Tên sản phẩm": data_raw[0], "Giá bán cũ": data_raw[1], "Giá mới": data_raw[2]}
    details = data_raw[3]
    titles = data_raw[4]
    for title, detail in zip(titles, details):
        data[title] = detail
    return data
def save_link_to_file(new_tags):
    import pickle
    # Lưu vào file
    with open('product_links_click_buy.pkl', 'wb') as file:
        pickle.dump(new_tags, file)
def load_file_link_to_file(file_name = 'product_links_click_buy.pkl'):
    import pickle
    with open(file_name, 'rb') as file:
        loaded_links = pickle.load(file)
    return loaded_links

if __name__ == "__main__":
    # # Set Chrome options
    # chrome_options = webdriver.ChromeOptions()
    # chrome_options.add_argument('--headless=new')  # Running Chrome in headless mode
    # chrome_options.add_argument('--no-sandbox')    # Necessary for running in some environments

    # # Automatically download and use the correct version of chromedriver
    # service = Service(ChromeDriverManager().install())

    # # Initialize the WebDriver with the service and options
    # driver = webdriver.Chrome(service=service, options=chrome_options)

    # Find product links
    # new_tags = find_link(driver)  
    new_tags = load_file_link_to_file()
    data = []
    feature_names = ["Tên sản phẩm", "Giá bán cũ", "Giá mới"]

    for count, tag_url in enumerate(new_tags, 1):
        # if count > 10:  
        #     break
        print(f'Liên kết: {count}')
        try:
            response = requests.get(tag_url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')

                # Find the div containing product specifications
                specifications = soup.find('div', class_='product-specification__content')

                if specifications:
                    lines = [line.strip() for line in specifications.get_text(separator='\n').strip().split('\n') if line.strip()]

                    titles = []
                    details = []

                    # Pair data into title and detail lists
                    for i in range(0, len(lines), 2):
                        title = lines[i].strip()
                        detail = lines[i + 1].strip() if (i + 1) < len(lines) else ''
                        titles.append(title)
                        details.append(detail)

              
                    price_old = soup.find('p', class_='price-old').get_text(strip=True)
                    price_new  = soup.find('p', class_='price').get_text(strip=True)
                    title_item = soup.find('h1', class_='product-name').get_text(strip=True)

 
                    print("Tiêu đề sản phẩm:", title_item)
                    print("Giá cũ:", price_new)
                    print("Giá mới:", price_old)
                    print("Tiêu đề cấu hình:", titles)
                    print("Chi tiết:", details)
                    print("Link:", tag_url)

                    data_raw = [title_item, price_new, price_old, details, titles]
                    data_done = prepare_data(data_raw)

                    for title in titles:
                        if title not in feature_names:
                            feature_names.append(title)
                    data.append(data_done)
                    print("******************************************************************************")
                else:
                    print("Không tìm thấy thẻ chứa thông số kỹ thuật.")
            else:
                print(f"Lỗi: {response.status_code} - {response.reason}")

        except Exception as e:
            print(f"Lỗi khi lấy thông tin từ {tag_url}: {str(e)}")


    save_to_csv(data, feature_names)
# Out:
# Liên kết: 1
# Tiêu đề sản phẩm: iPhone 15 Pro Max 256GB cũ đẹp 99%
# Giá cũ: 25.490.000 ₫
# Giá mới: 29.990.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-15-pro-max-cu
# ******************************************************************************
# Liên kết: 2
# Tiêu đề sản phẩm: iPhone 15 Pro 128GB cũ đẹp 99%
# Giá cũ: 20.190.000 ₫
# Giá mới: 26.990.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-15-pro-cu
# ******************************************************************************
# Liên kết: 3
# Tiêu đề sản phẩm: iPhone 15 Plus 128GB Cũ đẹp 99%
# Giá cũ: 18.290.000 ₫
# Giá mới: 23.990.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-15-plus-cu.html
# ******************************************************************************
# Liên kết: 4
# Tiêu đề sản phẩm: iPhone 14 Pro Max 128GB cũ đẹp 99%
# Giá cũ: 21.290.000 ₫
# Giá mới: 33.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Hãng sản xuất', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.7 inches', 'Apple A16 Bionic', 'iOS 16', '128GB', '6GB', 'Camera chính: 48MP Camera góc siêu rộng: 12MP Camera tele: 12MP', '4,352mAh', 'Space Black,Deep Purple,Silver,Gold', '1 Nano SIM & 1 eSIM, Hỗ trợ 5G', 'Apple', 'new', 'Apple']
# Link: https://clickbuy.com.vn/iphone-14-pro-max-128gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 5
# Tiêu đề sản phẩm: iPhone 14 Pro Max 256GB cũ đẹp 99%
# Giá cũ: 22.290.000 ₫
# Giá mới: 33.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Hãng sản xuất', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.7 inches', 'Apple A16 Bionic', 'iOS 16', '128GB', '6GB', 'Camera chính: 48MP Camera góc siêu rộng: 12MP Camera tele: 12MP', '4,352mAh', 'Space Black,Deep Purple,Silver,Gold', '1 Nano SIM & 1 eSIM, Hỗ trợ 5G', 'Apple', 'new', 'Apple']
# Link: https://clickbuy.com.vn/iphone-14-pro-max-256gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 6
# Tiêu đề sản phẩm: iPhone 14 Pro 128GB cũ đẹp 99%
# Giá cũ: 17.990.000 ₫
# Giá mới: 31.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Hãng sản xuất', 'Tình trạng SP']
# Chi tiết: ['6.1 inch', 'Apple A16 Bionic', 'iOS 16', '128GB', '6GB', 'Camera chính: 48MP Camera góc siêu rộng: 12MP Camera tele: 12MP', '3,200mAh', 'Space Black,Deep Purple,Silver,Gold', '2 Nano SIM (SIM 2 chung khe thẻ nhớ), Hỗ trợ 5G', 'Apple', 'new']
# Link: https://clickbuy.com.vn/iphone-14-pro-128gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 7
# Tiêu đề sản phẩm: iPhone 14 Plus 128GB cũ đẹp 99%
# Giá cũ: 14.490.000 ₫
# Giá mới: 31.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Màu sắc', 'Hãng sản xuất', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Apple A15 Bionic', 'iOS 16', '256 GB', '6 GB', 'Camera chính 12MP Camera góc siêu rộng 12MP', '12MP khẩu độ f/1.9', 'Black,Aura Red,Starlight,Aura Blue,Purple', 'Apple', 'new']
# Link: https://clickbuy.com.vn/iphone-14-plus-128gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 8
# Tiêu đề sản phẩm: iPhone 14 128GB Cũ đẹp 99%
# Giá cũ: 12.490.000 ₫
# Giá mới: 17.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Hãng sản xuất', 'Tình trạng SP', 'Tính năng màn hình']
# Chi tiết: ['6,1 inches', 'Apple A15 Bionic', 'iOS 16', '128GB', '6 GB', 'Camera góc rộng: 12MP Camera góc siêu rộng: 12MP', '3,279mAh', 'Black,Purple,Starlight,Red,Blue', 'Apple', 'new', 'Tần số quét 60Hz']
# Link: https://clickbuy.com.vn/iphone-14-128gb-chinh-hang-cu-99.html
# ******************************************************************************
# Liên kết: 9
# Tiêu đề sản phẩm: iPhone 13 Pro Max 128GB Cũ đẹp 99%
# Giá cũ: 15.990.000 ₫
# Giá mới: 27.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Tính năng đặc biệt']
# Chi tiết: ['6.7 inches', 'Apple A15', 'IOS 15', '128 GB', 'Camera tele : 12MP, /2.8', '12MP, ƒ/2.2', '4,325mAh', 'Black,Blue,Gold,Silver,Green', '2778 x 1284 pixel', '1 nano SIM + 1 eSIM', 'used', 'Hỗ trợ 5G, Kháng nước, kháng bụi, Sạc không dây, Nhận diện khuôn mặt']
# Link: https://clickbuy.com.vn/iphone-13-pro-max-128gb-chinh-hang-cu-99.html
# ******************************************************************************
# Liên kết: 10
# Tiêu đề sản phẩm: iPhone 13 Pro 128GB cũ đẹp 99%
# Giá cũ: 14.190.000 ₫
# Giá mới: 20.590.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6,1 inches', 'Apple A15', 'IOS 15', '128 GB', 'Camera tele : 12MP, /2.8', '12 MP', '3,095mAh', 'Green,Black,Blue,Gold,Silver', '1170 x 2532 pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-13-pro-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 11
# Tiêu đề sản phẩm: iPhone 12 Pro Max 128GB cũ đẹp 99%
# Giá cũ: 13.490.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Tình trạng sản phẩm']
# Chi tiết: ['6.7 inches', 'Apple A14 Bionic (5nm)', 'iOS 14', '128 GB', '6 GB', 'Cảm biến LiDAR', '12 MP', 'Li-Ion 3687 mAh', 'Graphite Black,Pacific Blue,Gold,Silver', '1284 x 2778 pixels', '1 nano SIM + 1 eSIM', 'used', 'Used']
# Link: https://clickbuy.com.vn/apple-iphone-12-pro-max-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 12
# Tiêu đề sản phẩm: iPhone 12 Pro Max 256GB cũ đẹp 99%
# Giá cũ: 14.190.000 ₫
# Giá mới: 33.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu', 'Tình trạng sản phẩm']
# Chi tiết: ['6.7 inches', 'Apple A14 Bionic (5nm)', 'iOS 14', '256 GB', '6 GB', 'Cảm biến LiDAR', '12 MP', 'Li-Ion 3687 mAh', 'Graphite Black,Pacific Blue,Gold,Silver', '1284 x 2778 pixels', '1 nano SIM + 1 eSIM', 'used', 'Apple', 'Used']
# Link: https://clickbuy.com.vn/apple-iphone-12-pro-max-256gb-cu-99.html
# ******************************************************************************
# Liên kết: 13
# Tiêu đề sản phẩm: iPhone 12 Pro 128GB Cũ đẹp 99%
# Giá cũ: 10.290.000 ₫
# Giá mới: 32.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Tinh trạng']
# Chi tiết: ['6.1 inch', 'Apple A14 Bionic (5nm)', 'iOS 14', '128 GB', '6 GB', 'Cảm biến LiDAR', '12 MP', 'Li-Ion 2815 mAh', 'Graphite Black,Pacific Blue,Gold,Silver', '1170 x 2532 pixels', 'used', 'Used']
# Link: https://clickbuy.com.vn/apple-iphone-12-pro-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 14
# Tiêu đề sản phẩm: iPhone 12 64GB cũ đẹp 99%
# Giá cũ: 7.990.000 ₫
# Giá mới: 24.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Tình trạng máy']
# Chi tiết: ['6.1 inch', 'Apple A14 Bionic (5nm)', 'iOS 14', '64 GB', '4 GB', 'Dual 12 MP', '12 MP', 'Li-Ion 2815 mAh', 'Blue,Black,Green,Red,White,Purple', '1170 x 2532 pixels', '1 nano SIM + 1 eSIM', 'used', 'Đã qua sử dụng']
# Link: https://clickbuy.com.vn/apple-iphone-12-64gb-cu-99.html
# ******************************************************************************
# Liên kết: 15
# Tiêu đề sản phẩm: Samsung Galaxy S24 (5G) Cũ Đẹp 99%
# Giá cũ: 11.990.000 ₫
# Giá mới: 22.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Sạc nhanh', 'Hãng sản xuất', 'Tình trạng SP']
# Chi tiết: ['6.2 inches', 'Snapdragon 8 Gen 3', 'Android 14, One UI 6.1', '128GB', '8GB', '50MP - 10MP - 12MP', '12MP', '4000 mAh', 'Black, Purple, Gray, Yellow', '1080 x 2340 pixels', '25W', 'Samsung', 'New']
# Link: https://clickbuy.com.vn/samsung-galaxy-s24-cu
# ******************************************************************************
# Liên kết: 16
# Tiêu đề sản phẩm: iPhone 11 Pro Max 64GB cũ đẹp 99%
# Giá cũ: 9.290.000 ₫
# Giá mới: 20.400.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.5"', 'Apple A13 Bionic (7 nm+)', 'iOS 13', '64 GB', '4 GB', 'Triple 12Mp + 12Mp + 12Mp', '12 MP', 'Li-Ion 3969mAh', 'Space Gray,Silver,Gold,Midnight Green', '1242 x 2688 Pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-11-pro-max-64gb-cu.html
# ******************************************************************************
# Liên kết: 17
# Tiêu đề sản phẩm: Samsung Galaxy S24 Plus (5G) Cũ Đẹp 99%
# Giá cũ: 15.790.000 ₫
# Giá mới: 26.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Sạc nhanh', 'Hãng sản xuất', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Snapdragon 8 Gen 3', 'Android 14, One UI 6.1', '256GB', '12GB', '50MP - 10MP - 12MP', '12MP', '4900 mAh', 'Black, Purple, Gray, Yellow, Orange, Blue, Green', '1440 x 3088 pixels', '45W', 'Samsung', 'New']
# Link: https://clickbuy.com.vn/samsung-s24-plus-cu
# ******************************************************************************
# Liên kết: 18
# Tiêu đề sản phẩm: iPhone 11 Pro 64GB cũ đẹp 99%
# Giá cũ: 7.590.000 ₫
# Giá mới: 17.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['5.8 inches', 'Apple A13 Bionic (7 nm+)', 'iOS 13', '64 GB', '4 GB', 'Triple 12Mp + 12Mp + 12Mp', '12 MP', 'Li-Ion 3190mAh', 'Space Gray,Silver,Gold,Midnight Green', '1125 x 2436 pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-11-pro-64gb-cu-99.html
# ******************************************************************************
# Liên kết: 19
# Tiêu đề sản phẩm: iPhone 11 64GB cũ đẹp 99%
# Giá cũ: 6.490.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.1 inch', 'Apple A13 Bionic (7 nm+)', 'iOS 13', '64 GB', '4 GB', 'Dual 12 MP', '12 MP', 'Li-Ion 3110mAh', 'Black,Red,Yellow,White,Green,Purple', '828 x 1792 pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-11-64gb-chinh-hang-cu.html
# ******************************************************************************
# Liên kết: 20
# Tiêu đề sản phẩm: Samsung Galaxy S22 Ultra (5G) 8GB 128GB Cũ đẹp 99%
# Giá cũ: 11.490.000 ₫
# Giá mới: 30.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['6,8 inches', 'Snapdragon 8 Gen 1 8 nhân', 'Android 12, One UI 4', '128 GB', '8Gb', '4 cam (108MP + 12MP + 10MP + 10 MP)', '40 MP', 'Li-Po 5000mAh', 'White,Black,Burgundy,Green', 'Quad HD+', '1 Nano SIM & 1 eSIM', 'Sạc nhanh 45W', 'Samsung', 'New']
# Link: https://clickbuy.com.vn/samsung-galaxy-s22-ultra-5g-8gb-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 21
# Tiêu đề sản phẩm: iPhone 11 Pro Max 256GB cũ đẹp 99%
# Giá cũ: 10.290.000 ₫
# Giá mới: 23.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.5"', 'Apple A13 Bionic (7 nm+)', 'iOS 13', '256 GB', '4 GB', 'Triple 12Mp + 12Mp + 12Mp', '12 MP', 'Li-Ion 3969mAh', 'Space Gray,Silver,Gold,Midnight Green', '1242 x 2688 Pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-11-pro-max-256gb-cu-99.html
# ******************************************************************************
# Liên kết: 22
# Tiêu đề sản phẩm: Samsung Galaxy S23 (5G) Cũ Đẹp 99%
# Giá cũ: 9.690.000 ₫
# Giá mới: 24.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Sạc nhanh', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.1 inch', 'Qualcomm SM8550 Snapdragon 8 Gen 2 (4 nm)', '128 GB', '8Gb', '50MP - 10MP - 12MP', '12MP', '3900 mAh', 'Green,Lavender,Cream,Aura Black', '1080 x 2340 pixels', 'Sạc nhanh 25W', 'new', 'Samsung']
# Link: https://clickbuy.com.vn/samsung-galaxy-s23-cu.html
# ******************************************************************************
# Liên kết: 23
# Tiêu đề sản phẩm: iPhone Xs MAX 64GB cũ đẹp 99%
# Giá cũ: 7.290.000 ₫
# Giá mới: 12.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP']
# Chi tiết: ['6.5"', 'Apple A12 Bionic 6 nhân', 'iOS 12', '64 GB', '4 GB', 'Dual 12 MP', '7.0 MP', 'Li-Ion 3174 mAh', 'Black,Silver White,Gold', '1242 x 2688 Pixels', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-xs-max-quoc-te-64gb-cu-99.html
# ******************************************************************************
# Liên kết: 24
# Tiêu đề sản phẩm: Samsung Galaxy S23 FE Cũ Đẹp 99%
# Giá cũ: 8.290.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Độ phân giải màn hình', 'Sạc nhanh', 'Hãng sản xuất']
# Chi tiết: ['6.4 inches', 'Snapdragon 8 Gen 1 (4 nm)', 'Android 13, upgradable to Android 14, One UI 6', '128GB', '8GB', '50MP - 8MP - 12MP', '10MP', 'Li-Ion 4500 mAh', '1080 x 2340 pixels', '25W', 'Samsung']
# Link: https://clickbuy.com.vn/galaxy-s23-fe-cu
# ******************************************************************************
# Liên kết: 25
# Tiêu đề sản phẩm: iPhone Xs 64Gb cũ đẹp 99%
# Giá cũ: 5.290.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['5.8 inches', 'iOS 12', '64 GB', '4GB', 'Dual 12 MP', '2658mAh', 'Silver White,Black,Gold', '1125 x 2436 pixels', '1 nano SIM', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-xs-64gb-quoc-te-cu-99.html
# ******************************************************************************
# Liên kết: 26
# Tiêu đề sản phẩm: iPhone 13 128GB Cũ đẹp 99%
# Giá cũ: 11.190.000 ₫
# Giá mới: 24.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6,1 inches', 'Apple A15', 'IOS 15', '128 GB', 'Camera góc siêu rộng: 12MP, ƒ/2.4', '12 MP', '3240mAh', 'Green,Black,Blue,Pink,Red,Silver', '2532 x 1170 pixels', '1 nano SIM + 1 eSIM', 'new']
# Link: https://clickbuy.com.vn/apple-iphone-13-128gb-chinh-hang-cu.html
# ******************************************************************************
# Liên kết: 27
# Tiêu đề sản phẩm: iPhone XR 64GB cũ đẹp 99%
# Giá cũ: 5.190.000 ₫
# Giá mới: 11.190.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['IPS LCD , 6.1 inches', 'Apple A12 Bionic 6 nhân', 'iOS 12', '64 GB', '3 GB', '12 MP', '7.0 MP', 'Li-Ion 2942 mAh', 'Orange,Royal Blue,Silver White,Black,Red,Gold', '828 x 1792 pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-xr-64gb-99.html
# ******************************************************************************
# Liên kết: 28
# Tiêu đề sản phẩm: Samsung Galaxy S21 Ultra (5G) 12GB 128GB Cũ đẹp 99%
# Giá cũ: 8.290.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.8 inches', 'Qualcomm SM8350 Snapdragon 888 5G (5 nm)', 'Android 11, One UI 3.1', '128GB', '12 GB', '108 MP, 12MP và 10MP+ 10MP+ 0.3 MP', '40MP', '5.000 mAh', 'Black,Copper,Silver', '1 Nano SIM & 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s21-ultra-5g-my-cu-99.html
# ******************************************************************************
# Liên kết: 29
# Tiêu đề sản phẩm: Samsung Galaxy S21 (5G) 8GB 128GB Cũ đẹp 99%
# Giá cũ: 5.890.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Sạc nhanh', 'Tình trạng SP']
# Chi tiết: ['6.2 inches', 'Qualcomm SM8350 Snapdragon 888 5G', 'OneUI 3.1', '128 GB', '8 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'microSDXC', 'Li-Po 4000mAH', 'Black,Silver,Violet,Rose Pink', 'Full HD+ (1080 x 2400 Pixels)', 'Sạc nhanh 25W', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s21-5g-cu.html
# ******************************************************************************
# Liên kết: 30
# Tiêu đề sản phẩm: Samsung Galaxy S21 Plus (5G) 8GB 128GB Cũ đẹp 99%
# Giá cũ: 6.790.000 ₫
# Giá mới: 25.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Qualcomm SM8350 Snapdragon 888 5G', 'OneUI 3.1', '128 GB', '8 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'microSDXC', 'Li-Po 4800mAh', 'Black,Silver,Violet', 'Full HD+ (1080 x 2400 Pixels)', '1 nano SIM', 'Sạc nhanh 25W', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s21-plus-5g-my-cu-99.html
# ******************************************************************************
# Liên kết: 31
# Tiêu đề sản phẩm: iPhone 14 Pro Max Lock 128GB
# Giá cũ: 16.590.000 ₫
# Giá mới: 33.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Hãng sản xuất', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.7 inches', 'Apple A16 Bionic', 'iOS 16', '128GB', '6GB', 'Camera chính: 48MP Camera góc siêu rộng: 12MP Camera tele: 12MP', '4,352mAh', 'Space Black,Deep Purple,Silver,Gold', '1 Nano SIM & 1 eSIM, Hỗ trợ 5G', 'Apple', 'new', 'Apple']
# Link: https://clickbuy.com.vn/iphone-14-pro-max-128gb-lock.html
# ******************************************************************************
# Liên kết: 32
# Tiêu đề sản phẩm: iPhone 8 64GB cũ đẹp 99%
# Giá cũ: 3.190.000 ₫
# Giá mới: 6.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu', 'Cảm biến']
# Chi tiết: ['4.7 inches', 'Apple A11 Bionic 6 nhân', 'iOS 12', '64 GB', '2GB', '12 MP', '7.0 MP', 'Li-Lon 1821 mAh', 'Black,Gold,Silver White,Red', 'HD (750 x 1334 Pixels)', '1 nano SIM', 'used', 'Apple', 'Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer']
# Link: https://clickbuy.com.vn/apple-iphone-8-64gb-quoc-te-cu-99.html
# ******************************************************************************
# Liên kết: 33
# Tiêu đề sản phẩm: iPhone 8 128GB cũ đẹp 99%
# Giá cũ: 3.390.000 ₫
# Giá mới: 6.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu', 'Cảm biến']
# Chi tiết: ['4.7 inches', 'Apple A11 Bionic 6 nhân', 'iOS 12', '64 GB', '2GB', '12 MP', '7.0 MP', 'Li-Lon 1821 mAh', 'Black,Gold,Silver White,Red', 'HD (750 x 1334 Pixels)', '1 nano SIM', 'used', 'Apple', 'Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer']
# Link: https://clickbuy.com.vn/iphone-8-128gb
# ******************************************************************************
# Liên kết: 34
# Tiêu đề sản phẩm: iPhone 8 Plus 64GB cũ đẹp 99%
# Giá cũ: 4.190.000 ₫
# Giá mới: 8.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu', 'Cảm biến']
# Chi tiết: ['5.5 inches', 'Apple A11 Bionic', '64 GB', '3 GB', 'Dual 12 MP', '7.0 MP', 'Li-Ion 2691 mAh', 'Red,Gold,Black,Silver White', '1920 x 1080 pixel (~401 ppi)', '1 nano SIM', 'used', 'Apple', 'Fingerprint (front-mounted), accelerometer, gyro, proximity, compass, barometer']
# Link: https://clickbuy.com.vn/apple-iphone-8-plus-64gb-likenew-99.html
# ******************************************************************************
# Liên kết: 35
# Tiêu đề sản phẩm: iPhone 12 128GB cũ đẹp 99%
# Giá cũ: 8.590.000 ₫
# Giá mới: 19.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.1 inch', 'Apple A14 Bionic (5nm)', 'iOS 14', '128GB', '4 GB', 'Dual 12 MP', '12 MP', 'Li-Ion 2815 mAh', 'Blue,Black,Green,Red,White,Purple', '1170 x 2532 pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-12-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 36
# Tiêu đề sản phẩm: iPhone 11 Pro 256GB cũ đẹp 99%
# Giá cũ: 8.490.000 ₫
# Giá mới: 18.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['5.8 inches', 'Apple A13 Bionic (7 nm+)', 'iOS 13', '256 GB', '4 GB', 'Triple 12Mp + 12Mp + 12Mp', '12 MP', 'Li-Ion 3190mAh', 'Space Gray,Silver,Gold,Midnight Green', '1125 x 2436 pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-11-pro-256gb-cu-99.html
# ******************************************************************************
# Liên kết: 37
# Tiêu đề sản phẩm: iPhone 13 Lock 128GB Cũ đẹp 99%
# Giá cũ: 8.390.000 ₫
# Giá mới: 24.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6,1 inches', 'Apple A15', 'IOS 15', '128 GB', 'Camera góc siêu rộng: 12MP, ƒ/2.4', '12 MP', '3240mAh', 'Black,Green,Blue,Pink,Red,Silver', '2532 x 1170 pixels', '1 nano SIM + 1 eSIM', 'new']
# Link: https://clickbuy.com.vn/iphone-13-128gb-lock-cu-dep-99.html
# ******************************************************************************
# Liên kết: 38
# Tiêu đề sản phẩm: iPhone 11 128Gb cũ đẹp 99%
# Giá cũ: 7.490.000 ₫
# Giá mới: 15.790.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.1 inch', 'Apple A13 Bionic (7 nm+)', 'iOS 13', '128 GB', '4 GB', 'Dual 12 MP', '12 MP', 'Li-Ion 3110mAh', 'Red,Black,Yellow,White,Green,Purple', '828 x 1792 pixels', '1 nano SIM + 1 eSIM', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-11-128gb-chinh-hang-cu.html
# ******************************************************************************
# Liên kết: 39
# Tiêu đề sản phẩm: iPhone Xs 256Gb cũ đẹp 99%
# Giá cũ: 5.690.000 ₫
# Giá mới: 7.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['5.8 inches', 'iOS 12', '256 GB', '4GB', 'Dual 12 MP', '2658mAh', 'Silver White,Black,Gold', '1125 x 2436 pixels', '1 nano SIM', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-xs-256gb-quoc-te-cu-99.html
# ******************************************************************************
# Liên kết: 40
# Tiêu đề sản phẩm: Samsung Galaxy S21 FE (5G) 128GB Cũ đẹp 99%
# Giá cũ: 5.190.000 ₫
# Giá mới: 16.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu', 'Tình trạng máy', 'Công nghệ sạc']
# Chi tiết: ['6.4 inches', 'Snapdragon 888', 'Android 12, One UI 4', '128GB', '6GB', 'Camera góc rộng: 12 MP, f/1.8, PDAF, OIS Camera tele: 8 MP, f/2.4, 3x optical zoom Camera góc siêu rộng: 12 MP, f/2.2', '32 MP, f/2.2', '4500 mAh', 'Black,Green,Violet,White', '1080 x 2400 pixels (FullHD+)', '1 SIM (Nano-SIM)', 'new', 'Samsung', 'New', 'Sạc nhanh: 25WSạc nhanh không dây 15WSạc không dây ngược 4,5W']
# Link: https://clickbuy.com.vn/samsung-galaxy-s21-fe-5g-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 41
# Tiêu đề sản phẩm: iPhone Xs MAX 256GB cũ đẹp 99%
# Giá cũ: 7.990.000 ₫
# Giá mới: 15.390.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.5"', 'Apple A12 Bionic 6 nhân', 'iOS 12', '256 GB', '4 GB', 'Dual 12 MP', '7.0 MP', 'Li-Ion 3174 mAh', 'Black,Gold,Silver White', '1242 x 2688 Pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-xs-max-quoc-te-256gb-cu-99.html
# ******************************************************************************
# Liên kết: 42
# Tiêu đề sản phẩm: Apple iPhone 7 32GB cũ 99%
# Giá cũ: 2.590.000 ₫
# Giá mới: 4.290.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Cảm biến']
# Chi tiết: ['4.7 inches', 'Apple A10 Fusion', 'iOS 10', '32 GB', '2GB', '12 MP', '7.0 MP', 'Li-Po 1960 mAh', 'Jet Black,Rose,Silver White,Black,Gold', '750 x 1334 pixel (~326 ppi)', '1 nano SIM', 'Fingerprint (front-mounted), accelerometer, gyro, proximity, compass']
# Link: https://clickbuy.com.vn/apple-iphone-7-32gb-cu-99.html
# ******************************************************************************
# Liên kết: 43
# Tiêu đề sản phẩm: iPhone 13 Pro 256GB cũ đẹp 99%
# Giá cũ: 14.590.000 ₫
# Giá mới: 20.590.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6,1 inches', 'Apple A15', 'IOS 15', '256 GB', 'Camera tele : 12MP, /2.8', '12 MP', '3,095mAh', 'Green,Black,Blue,Gold,Silver', '1170 x 2532 pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/apple-iphone-13-pro-256gb-cu-99.html
# ******************************************************************************
# Liên kết: 44
# Tiêu đề sản phẩm: iPhone XR 128GB cũ đẹp 99%
# Giá cũ: 5.790.000 ₫
# Giá mới: 11.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['IPS LCD , 6.1 inches', 'Apple A12 Bionic 6 nhân', 'iOS 12', '128 GB', '3 GB', '12 MP', '7.0 MP', 'Li-Ion 2942 mAh', 'Orange,Royal Blue,Silver White,Black,Red,Gold', '828 x 1792 pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-xr-128gb-quoc-te-cu-99.html
# ******************************************************************************
# Liên kết: 45
# Tiêu đề sản phẩm: iPhone X 256GB cũ đẹp 99%
# Giá cũ: 5.390.000 ₫
# Giá mới: 12.190.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['5.8 inches', 'Apple A11 Bionic', 'Apple iOS', '256 GB', '3 GB', 'Dual 12 MP', '7.0 MP', 'Li-Ion 2716 mAh', 'Dark Grey,Silver White', 'OLED, Super Retina', '1 nano SIM', 'Apple', 'Đã qua sử dụng']
# Link: https://clickbuy.com.vn/apple-iphone-x-256gb-quoc-te-cu-99.html
# ******************************************************************************
# Liên kết: 46
# Tiêu đề sản phẩm: iPhone 13 Pro Max 256GB Cũ đẹp 99%
# Giá cũ: 16.990.000 ₫
# Giá mới: 34.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Tính năng đặc biệt']
# Chi tiết: ['6.7 inches', 'Apple A15', 'IOS 15', '128 GB', 'Camera tele : 12MP, /2.8', '12MP, ƒ/2.2', '4,325mAh', 'Black,Blue,Gold,Silver,Green', '2778 x 1284 pixel', '1 nano SIM + 1 eSIM', 'used', 'Hỗ trợ 5G, Kháng nước, kháng bụi, Sạc không dây, Nhận diện khuôn mặt']
# Link: https://clickbuy.com.vn/iphone-13-pro-max-256gb-chinh-hang-cu-99.html
# ******************************************************************************
# Liên kết: 47
# Tiêu đề sản phẩm: iPhone 13 256GB Cũ đẹp 99%
# Giá cũ: 12.790.000 ₫
# Giá mới: 24.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6,1 inches', 'Apple A15', 'IOS 15', '128 GB', 'Camera góc siêu rộng: 12MP, ƒ/2.4', '12 MP', '3240mAh', 'Green,Black,Blue,Pink,Red,Silver', '2532 x 1170 pixels', '1 nano SIM + 1 eSIM', 'new']
# Link: https://clickbuy.com.vn/apple-iphone-13-256gb-chinh-hang-cu.html
# ******************************************************************************
# Liên kết: 48
# Tiêu đề sản phẩm: iPhone 14 Lock 128GB
# Giá cũ: 9.990.000 ₫
# Giá mới: 21.490.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-14-lock-128gb.html
# ******************************************************************************
# Liên kết: 49
# Tiêu đề sản phẩm: iPhone 14 Plus 256GB cũ đẹp 99%
# Giá cũ: 15.690.000 ₫
# Giá mới: 31.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Màu sắc', 'Hãng sản xuất', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Apple A15 Bionic', 'iOS 16', '256 GB', '6 GB', 'Camera chính 12MP Camera góc siêu rộng 12MP', '12MP khẩu độ f/1.9', 'Black,Aura Red,Starlight,Aura Blue,Purple', 'Apple', 'new']
# Link: https://clickbuy.com.vn/iphone-14-plus-256gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 50
# Tiêu đề sản phẩm: iPhone 15 Plus 256GB Cũ đẹp 99%
# Giá cũ: 20.390.000 ₫
# Giá mới: 23.990.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-15-plus-256gb-cu
# ******************************************************************************
# Liên kết: 51
# Tiêu đề sản phẩm: Apple iPhone 7 plus 128GB cũ 99%
# Giá cũ: 3.690.000 ₫
# Giá mới: 5.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Thương hiệu', 'Tình trạng máy', 'Cảm biến']
# Chi tiết: ['5.5 inches', 'Apple A10 Fusion', 'iOS 10', '32 GB', '3 GB', '12 MP', '7.0 MP', 'Li-Ion 2900 mAh', 'Jet Black,Rose,Silver White,Black,Gold', '1920 x 1080 pixel (~401 ppi)', '1 nano SIM', 'Apple', 'Đã qua sử dụng', 'Fingerprint (front-mounted), accelerometer, gyro, proximity, compass']
# Link: https://clickbuy.com.vn/apple-iphone-7-plus-128gb-cu-chinh-hang-99.html
# ******************************************************************************
# Liên kết: 52
# Tiêu đề sản phẩm: Apple iPhone Xs 512Gb cũ 99%
# Giá cũ: 6.390.000 ₫
# Giá mới: 13.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['5.8 inches', 'iOS 12', '512GB', '4GB', 'Dual 12 MP', '2658mAh', 'Silver White,Black,Gold', '1125 x 2436 pixels', '1 nano SIM', 'Apple', 'Đã qua sử dụng']
# Link: https://clickbuy.com.vn/apple-iphone-xs-512gb-quoc-te-cu-99.html
# ******************************************************************************
# Liên kết: 53
# Tiêu đề sản phẩm: Samsung Galaxy S20 FE (5G) 128GB cũ ( 2 sim Vật Lý)
# Giá cũ: 4.690.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim']
# Chi tiết: ['6.5 inches', 'Snapdragon 865', 'Android 10, One UI 2.5', '128GB', '6GB', 'Camera chính: 12 MP, f/1.8 Camera tele: 8 MP, f/2.0, zoom quang 3x Camera góc siêu rộng: 12 MP, f/2.2', '32 MP, f/2.0, AF', 'Li-Po 4500 mAh, sạc nhanh 25W, sạc không dây cho các thiết bị ngoại vi 5.4W', 'Xanh Dương,Xanh Lá,Cam', '1 nano SIM']
# Link: https://clickbuy.com.vn/samsung-galaxy-s20-fe-5g-128gb-cu.html
# ******************************************************************************
# Liên kết: 54
# Tiêu đề sản phẩm: iPhone 15 128GB cũ đẹp 99%
# Giá cũ: 15.390.000 ₫
# Giá mới: 20.990.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-15-cu.html
# ******************************************************************************
# Liên kết: 55
# Tiêu đề sản phẩm: iPhone 15 256GB cũ đẹp 99%
# Giá cũ: 16.790.000 ₫
# Giá mới: 20.990.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-15-256gb-cu
# ******************************************************************************
# Liên kết: 56
# Tiêu đề sản phẩm: Samsung Galaxy Z Flip5 Cũ đẹp 99%
# Giá cũ: 10.490.000 ₫
# Giá mới: 25.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Sạc nhanh', 'Hãng sản xuất', 'Tình trạng SP', 'Màn Hinh Phụ']
# Chi tiết: ['6.7 inches', 'Snapdragon 8 Gen 2 for Galaxy', 'Android 13, One UI 5.1', '256 GB', '8Gb', '12MP - 12MP', '10 MP', '3700 mAh', 'Ocean Green,Lavender,Graphite Black,Cream', '1080 x 2640 pixels', 'Sạc nhanh 25W', 'Samsung', 'new', '3,4 inchs']
# Link: https://clickbuy.com.vn/samsung-galaxy-z-flip5-cu
# ******************************************************************************
# Liên kết: 57
# Tiêu đề sản phẩm: Samsung Galaxy S22 128GB cũ đẹp 99%
# Giá cũ: 6.990.000 ₫
# Giá mới: 21.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['6.1 inch', 'Snapdragon 8 Gen 1 8 nhân', 'Android 12, One UI 4', '128 GB', '8Gb', '50MP – 10MP – 12MP', '10 MP', 'Li-Po 3700mAh', 'Rose Gold,Aura White,Mystic Green,Aura Black', '1080 x 2340 pixels (Full HD+)', '2 nano SIM', 'Sạc nhanh 45W', 'Samsung', 'New']
# Link: https://clickbuy.com.vn/samsung-galaxy-s22-5g-8gb-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 58
# Tiêu đề sản phẩm: Samsung Galaxy S22 Plus (5G) 128GB cũ đẹp 99%
# Giá cũ: 8.190.000 ₫
# Giá mới: 14.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['6.6 inches', 'Snapdragon 8 Gen 1 8 nhân', 'Android 12, One UI 4', '128 GB', '8Gb', '50MP – 10MP – 12MP', '10 MP', '4500 mAh', 'Green,Black,White,Pink Gold', '1080 x 2340 pixels (Full HD+)', '1 Nano SIM & 1 eSIM', 'Sạc nhanh 25W', 'Samsung', 'New']
# Link: https://clickbuy.com.vn/samsung-galaxy-s22-plus-5g-128gb-my-2-sim-cu-99.html
# ******************************************************************************
# Liên kết: 59
# Tiêu đề sản phẩm: Samsung Galaxy S20 Plus 8G 128GB cũ ( 2 sim vật lý)
# Giá cũ: 5.490.000 ₫
# Giá mới: 7.890.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Exynos 990', 'Android 10', '128 GB', '8 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'Hỗ trợ thẻ nhớ 1TB', 'Li-Ion 4500mAh', 'Aura Blue,Mountain Gray,Aura Black,Red,Aura White', '1440 x 3200 pixels', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s20-plus-cu.html
# ******************************************************************************
# Liên kết: 60
# Tiêu đề sản phẩm: Samsung Galaxy S22 Ultra (5G) 12GB 256GB cũ đẹp 99%
# Giá cũ: 12.190.000 ₫
# Giá mới: 30.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['6,8 inches', 'Snapdragon 8 Gen 1 8 nhân', 'Android 12, One UI 4', '256 GB', '12 GB', '4 cam (108MP + 12MP + 10MP + 10 MP)', '40 MP', 'Li-Po 5000mAh', 'White,Black,Burgundy,Green', 'Quad HD+', '1 Nano SIM & 1 eSIM', 'Sạc nhanh 45W', 'Samsung', 'New']
# Link: https://clickbuy.com.vn/samsung-galaxy-s22-ultra-5g-12gb-256gb-cu-99.html
# ******************************************************************************
# Liên kết: 61
# Tiêu đề sản phẩm: iPhone 12 Pro 256GB cũ đẹp 99%
# Giá cũ: 11.290.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.1 inch', 'Apple A14 Bionic (5nm)', 'iOS 14', '256 GB', '6 GB', 'Cảm biến LiDAR', '12 MP', 'Li-Ion 2815 mAh', 'Graphite Black,Pacific Blue,Gold,Silver', '1170 x 2532 pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-12-pro-2568gb-cu-99.html
# ******************************************************************************
# Liên kết: 62
# Tiêu đề sản phẩm: iPhone 14 Pro 256GB cũ đẹp 99%
# Giá cũ: 19.490.000 ₫
# Giá mới: 29.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Hãng sản xuất', 'Tình trạng SP']
# Chi tiết: ['6.1 inch', 'Apple A16 Bionic', 'iOS 16', '1 TB', '6GB', 'Camera chính: 48MP Camera góc siêu rộng: 12MP Camera tele: 12MP', '3,200mAh', 'Deep Purple,Space Black,Silver,Gold', '2 Nano SIM (SIM 2 chung khe thẻ nhớ), Hỗ trợ 5G', 'Apple', 'new']
# Link: https://clickbuy.com.vn/iphone-14-pro-256gb-cu.html
# ******************************************************************************
# Liên kết: 63
# Tiêu đề sản phẩm: iPhone 14 Pro 128GB Lock
# Giá cũ: 14.990.000 ₫
# Giá mới: 31.990.000 ₫
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-14-pro-128gb-lock
# ******************************************************************************
# Liên kết: 64
# Tiêu đề sản phẩm: Sony Xperia 1 III (Mark 3) 12GB|256GB Nhật Cũ 99%
# Giá cũ: 7.990.000 ₫
# Giá mới: 15.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.5 inches', 'Qualcomm SM8350 Snapdragon 888 5G (5 nm)', '256 GB', '12 GB', '12 MP, f/2.2, 124˚, 16mm (ultrawide), 1/2.6", Dual Pixel PDAF 0.3 MP, TOF 3D, (depth)', '1080p@30fps, 5-axis gyro-EIS', '4500 mAh', 'Purple,Black,Gray', '1 micro SIM', 'used']
# Link: https://clickbuy.com.vn/sony-xperia-1-iii-mark-3-12gb-256gb-nhat-cu-99.html
# ******************************************************************************
# Liên kết: 65
# Tiêu đề sản phẩm: iPhone X 64GB cũ đẹp 99%
# Giá cũ: 4.690.000 ₫
# Giá mới: 9.490.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['5.8 inches', 'Apple A11 Bionic', 'Apple iOS', '64 GB', '3 GB', 'Dual 12 MP', '7.0 MP', 'Li-Ion 2716 mAh', 'Dark Grey,Silver White', 'OLED, Super Retina', '1 nano SIM', 'Apple', 'Đã qua sử dụng']
# Link: https://clickbuy.com.vn/apple-iphone-x-64gb-cu.html
# ******************************************************************************
# Liên kết: 66
# Tiêu đề sản phẩm: iPhone 12 mini 64GB cũ đẹp 99%
# Giá cũ: 6.190.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-12-mini-64gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 67
# Tiêu đề sản phẩm: iPhone Xs MAX 512GB cũ đẹp 99%
# Giá cũ: 8.090.000 ₫
# Giá mới: 15.890.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.5"', 'Apple A12 Bionic 6 nhân', 'iOS 12', '512 GB', '4 GB', 'Dual 12 MP', '7.0 MP', 'Li-Ion 3174 mAh', 'Black,Silver White,Gold', '1242 x 2688 Pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-xs-max-512gb-quoc-te-cu-dep-99.html
# ******************************************************************************
# Liên kết: 68
# Tiêu đề sản phẩm: Điện thoại Sony Xperia 5 II ( Mark2) cũ 99%
# Giá cũ: 4.190.000 ₫
# Giá mới: 6.990.000 ₫
# Tiêu đề cấu hình: ['CPU', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Hãng sản xuất', 'Tình trạng SP', 'Màn hình', 'Jack tai nghe', 'Chất liệu', 'Cổng kết nối/sạc', 'Danh bạ']
# Chi tiết: ['Snapdragon 865', '128 GB', '8 GB', 'Chính 12 MP & Phụ 12 MP, 12 MP', '8 MP', 'MicroSD', '4000 mAh', 'Black,Blue,Gray,Purple', '1-2 SIM, Nano SIM', 'Sony', 'used', 'OLED6.1", Full HD+', '3.5 mm', 'Khung nhôm & Mặt lưng kính cường lực', 'Type-C', 'Không giới hạn']
# Link: https://clickbuy.com.vn/dien-thoai-sony-xperia-5-ii.html
# ******************************************************************************
# Liên kết: 69
# Tiêu đề sản phẩm: Samsung Galaxy S20 (5G) 12GB 128GB Cũ
# Giá cũ: 4.990.000 ₫
# Giá mới: 11.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.2 inches', 'Qualcomm SM8250 Snapdragon 865 5G', 'Android 10', '128 GB', '8 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'Hỗ trợ thẻ nhớ 1TB', 'Li-Ion 4000 mAh', 'Aura Black,Pink Mist,Aura White,Aura Blue', '1440 x 3200 pixels', '1 nano SIM + 1 eSIM', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s20-5g-cu-99.html
# ******************************************************************************
# Liên kết: 70
# Tiêu đề sản phẩm: iPhone 12 Pro 512GB cũ đẹp 99%
# Giá cũ: 11.790.000 ₫
# Giá mới: 32.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.1 inch', 'Apple A14 Bionic (5nm)', 'iOS 14', '512GB', '6 GB', 'Cảm biến LiDAR', '12 MP', 'Li-Ion 2815 mAh', 'Graphite Black,Pacific Blue,Gold,Silver', '1170 x 2532 pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/iphone-12-pro-512gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 71
# Tiêu đề sản phẩm: iPad Gen 6 Wifi 32GB cũ 99%
# Giá cũ: 3.990.000 ₫
# Giá mới: 7.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['9.7 inches', 'Apple GPU ( 4 nhân )', 'iOS 11', '32 GB', '2GB', '8.0 MP', '1.2 MP', 'Không hỗ trợ thẻ nhớ', '32.4 Wh (~ 8600 mAh)', 'Rose Gold,Artic Silver,Black', '1536 x 2048 pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/ipad-gen-6.html
# ******************************************************************************
# Liên kết: 72
# Tiêu đề sản phẩm: iPad Air 2 LTE 16GB Cũ 98%
# Giá cũ: 2.490.000 ₫
# Giá mới: 6.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['9.7 inches', 'Apple A8X', 'iOS 9.3.3 (có thể up lên iOS 10)', '16GB', '2GB', '8.0 MP', '1.2 MP', 'Không hỗ trợ thẻ nhớ', 'Li-Po 8827 mAh', 'Black,Gold,White', '1536 x 2048 pixels', '1 nano SIM', 'used', 'Apple']
# Link: https://clickbuy.com.vn/ipad-air-2-lte-16gb-chinh-hang-cu-95.html
# ******************************************************************************
# Liên kết: 73
# Tiêu đề sản phẩm: iPad Air 2 LTE 32GB cũ 99%
# Giá cũ: 2.699.000 ₫
# Giá mới: 7.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['9.7 inches', 'Apple A8X', 'iOS 9.3.3 (có thể up lên iOS 10)', '32 GB', '2GB', '8.0 MP', '1.2 MP', 'Không hỗ trợ thẻ nhớ', 'Li-Po 8827 mAh', 'Black,Gold,White', '1536 x 2048 pixels', '1 nano SIM', 'used', 'Apple']
# Link: https://clickbuy.com.vn/ipad-air-2-4g-32gb-cu-99.html
# ******************************************************************************
# Liên kết: 74
# Tiêu đề sản phẩm: iPad Air 1 Wifi 16GB cũ 99%
# Giá cũ: 1.990.000 ₫
# Giá mới: 4.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thương hiệu', 'Tình trạng máy']
# Chi tiết: ['9.7 inches', 'Apple A7', 'iOS 9.3.3 (có thể up lên iOS 10)', '16GB', '1GB', '5 MP', '1.2 MP', 'Không hỗ trợ thẻ nhớ', 'Li-Po 8820 mAh', 'Black,White', '1536 x 2048 pixels', 'Apple', 'Đã qua sử dụng']
# Link: https://clickbuy.com.vn/ipad-air-wifi-16gb-cu-99.html
# ******************************************************************************
# Liên kết: 75
# Tiêu đề sản phẩm: iPad Air 1 LTE 16GB cũ 99%
# Giá cũ: 1.990.000 ₫
# Giá mới: 4.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['9.7 inches', 'Apple A7', 'iOS 9.3.3 (có thể up lên iOS 10)', '16GB', '1GB', '5 MP', '1.2 MP', 'Không hỗ trợ thẻ nhớ', 'Li-Po 8820 mAh', 'Black,White', '1536 x 2048 pixels', '1 nano SIM', 'used', 'Apple']
# Link: https://clickbuy.com.vn/ipad-air-16g-4g-wifi-cu-99.html
# ******************************************************************************
# Liên kết: 76
# ...
# Chi tiết: ['6,7 icnhes', 'Qualcomm SM8250 Snapdragon 865+ (7 nm+)', 'Android 10', '128GB', '8 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'Không hỗ trợ thẻ nhớ', '4.300mAh', 'Mystic Bronze,Mystic Gray,Mystic Green', 'Full HD+ (1080 x 2400 Pixels)', 'Sạc nhanh 25W', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-note-20-cu.html
# ******************************************************************************
# Liên kết: 183
# Tiêu đề sản phẩm: Samsung S20 Ultra (5G) 12GB 128GB Mỹ Cũ
# Giá cũ: 6.990.000 ₫
# Giá mới: 14.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP']
# Chi tiết: ['6.9 inches', 'Qualcomm Snapdragon 865', 'Android 10, upgradable to Android 11, One UI 3.0', '128GB', '12 GB', '108MP + 48MP + 12MP', '40MP', 'Black,Gray', '1440 x 3200 pixels', 'used']
# Link: https://clickbuy.com.vn/samsung-s20-ultra-5g-my-128gb.html
# ******************************************************************************
# Liên kết: 184
# Tiêu đề sản phẩm: iPhone 13 mini cũ đẹp 128GB 99%
# Giá cũ: 9.490.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: []
# Chi tiết: []
# Link: https://clickbuy.com.vn/iphone-13-mini-128gb-cu-dep-99.html
# ******************************************************************************
# Liên kết: 185
# Tiêu đề sản phẩm: iPhone 12 256GB cũ đẹp 99%
# Giá cũ: 9.390.000 ₫
# Giá mới: 24.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.1 inch', 'Apple A14 Bionic (5nm)', 'iOS 14', '256 GB', '4 GB', 'Dual 12 MP', '12 MP', 'Li-Ion 2815 mAh', 'Blue,Black,Green,Red,White', '1170 x 2532 pixels', 'used', 'Apple']
# Link: https://clickbuy.com.vn/apple-iphone-12-256gb-cu-99.html
# ******************************************************************************
# Liên kết: 186
# Tiêu đề sản phẩm: Samsung Galaxy S10 Plus 512GB Hàn Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh']
# Chi tiết: ['6.4 inches', 'Exynos 9820 8 nhân 64-bit', 'Android 9.0 (Pie)', '512 GB', '8 GB', '12 MP+12MP+16MP, LED Flash', '10 MP+8MP', 'Hỗ trợ thẻ nhớ 512Gb', 'Li-lon 4100 mAh', 'Black Ceramic,White Crystal,Navy Blue', '1440 x 3040 pixels', '1 nano SIM', 'Quick Charge 2.0']
# Link: https://clickbuy.com.vn/samsung-galaxy-s10-plus-512gb-han-99.html
# ******************************************************************************
# Liên kết: 187
# Tiêu đề sản phẩm: Samsung Galaxy Note 10 256GB Mỹ Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh']
# Chi tiết: ['6.3 inches', 'Exynos 9825', 'Android 9.0 (Pie)', '256 GB', '8 GB', '12 MP+12MP+16MP, LED Flash', '10MP (ToF)', 'Hỗ trợ thẻ nhớ 512Gb', '3500 mAh', 'Aura Black,Aura Blue,Aura Glow,Aura Red', '1080 x 2280 pixels', '1 nano SIM', 'Sạc nhanh 45W']
# Link: https://clickbuy.com.vn/samsung-galaxy-note-10-cu-256gb.html
# ******************************************************************************
# Liên kết: 188
# Tiêu đề sản phẩm: Galaxy Z Fold2 (5G) 256GB Hàn Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Thương hiệu', 'Tình trạng máy', 'Camera ngoài', 'GPU']
# Chi tiết: ['Snapdragon 888 (5nm)', 'Android 11', '256GB & 512GB', '12 GB', 'Tele: 12MP, F2.4', '4MP, F1.8', '4400 mAh Sạc nhanh 25W/Sạc không dây 10W Chia sẻ Pin không dây', 'Green,Black,Silver', 'Màn hình phụ: 6.2 inch, 2268 x 832 (HD+), Dynamic AMOLED 2X 120Hz', 'Nano SIM + eSIM', 'Samsung', 'New', '10MP, F2.2', '8 nhân']
# Link: https://clickbuy.com.vn/galaxy-z-fold2-5g-256gb-han-cu-99.html
# ******************************************************************************
# Liên kết: 189
# Tiêu đề sản phẩm: Samsung Galaxy A82 (5G) (SM-A826S) Hàn Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Snapdragon 855+', 'Android 11', '128GB', '6GB', '64MP + 12MP + 5MP', '10 MP, f / 2.2, (rộng)', '4500 mAh', 'Black,Violet,White', '1440 x 3200 pixel', '1 nano SIM', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-a82-5g-sm-a826s-han-cu-99.html
# ******************************************************************************
# Liên kết: 190
# Tiêu đề sản phẩm: Samsung Galaxy S20 Plus (5G) 12GB 256GB Hàn Cũ đẹp 99%
# Giá cũ: 6.190.000 ₫
# Giá mới: 23.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Qualcomm SM8250 Snapdragon 865 5G', 'Android 10', '256 GB', '12 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'Hỗ trợ thẻ nhớ 1TB', 'Li-Ion 4500mAh', 'Aura Blue,Aura Black,Mountain Gray', '1440 x 3200 pixels', 'used']
# Link: https://clickbuy.com.vn/galaxy-s20-plus-5g-12gb-256gb-han-cu
# ******************************************************************************
# Liên kết: 191
# Tiêu đề sản phẩm: Samsung Galaxy S20 Plus (5G) 12GB 128GB Mỹ Cũ đẹp 99%
# Giá cũ: 5.790.000 ₫
# Giá mới: 23.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP']
# Chi tiết: ['6.7 inches', 'Qualcomm SM8250 Snapdragon 865 5G', 'Android 10', '128 GB', '12 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'Hỗ trợ thẻ nhớ 1TB', 'Li-Ion 4500mAh', 'Aura Blue,Aura Black,Mountain Gray', '1440 x 3200 pixels', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s20-plus-5g-cu-99.html
# ******************************************************************************
# Liên kết: 192
# Tiêu đề sản phẩm: iPhone 11 64GB Chính hãng TBH
# Giá cũ: 7.990.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu']
# Chi tiết: ['6.1 inch', 'Apple A13 Bionic (7 nm+)', 'iOS 13', '64GB', '4 GB', 'Dual 12 MP', '12 MP', 'Li-Ion 3110mAh', 'Yellow,Black,Green,White,Purple,Red', '828 x 1792 pixels', '1 nano SIM + 1 eSIM', 'refurbished', 'Apple']
# Link: https://clickbuy.com.vn/iphone-11-64gb-chinh-hang-vna-troi-bao-hanh.html
# ******************************************************************************
# Liên kết: 193
# Tiêu đề sản phẩm: Samsung Note 10 Plus (5G) 256GB Hàn Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Tình trạng SP']
# Chi tiết: ['6.8 inches', 'Exynos 9825', 'Android 9.0 (Pie)', '256 GB', '12 GB', '12 MP+12MP+16MP, LED Flash', '10MP (ToF)', 'Hỗ trợ thẻ nhớ 512Gb', '4.300mAh', 'Aura Black,Aura Blue,Aura Glow,Aura Red,Aura White', '1440 x 3040 pixels', '1 nano SIM', 'Sạc nhanh 45W', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-note-10-plus-han-cu-99-ban-5g.html
# ******************************************************************************
# Liên kết: 194
# Tiêu đề sản phẩm: Samsung Galaxy S10 Plus 128GB Hàn Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh']
# Chi tiết: ['6.4 inches', 'Exynos 9820 8 nhân', 'Android 9.0 (Pie)', '128 GB', '8 GB', '12 MP+12MP+16MP, LED Flash', '10 MP+8MP', 'Hỗ trợ thẻ nhớ 512Gb', 'Li-lon 4100 mAh', 'Black Ceramic,Flamingo Pink,White Crystal,Navy Blue', '1440 x 3040 pixels', '1 nano SIM', 'Quick Charge 2.0']
# Link: https://clickbuy.com.vn/samsung-galaxy-s10-plus-128gb-cu-99.html
# ******************************************************************************
# Liên kết: 195
# Tiêu đề sản phẩm: Samsung Galaxy Note 10 Plus 256GB Mỹ Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Tình trạng SP']
# Chi tiết: ['6.8 inches', 'Qualcomm Snapdragon 855', 'Android 9.0 (Pie)', '256 GB', '12 GB', '12 MP+12MP+16MP, LED Flash', '10MP (ToF)', 'Hỗ trợ thẻ nhớ 512Gb', '4.300mAh', 'Aura Black,Aura Blue,Aura Glow,Aura White', '1440 x 3040 pixels', '1 nano SIM', 'Sạc nhanh 45W', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-note-10-plus-256gb-my-cu-99.html
# ******************************************************************************
# Liên kết: 196
# Tiêu đề sản phẩm: Samsung Galaxy Note 9 Mỹ Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim']
# Chi tiết: ['6.4 inches', 'Qualcomm Snapdragon 845', 'Android OS, v8.1', '128 GB', '6 GB', 'Dual 12 MP', '8.0 MP', 'Hỗ trợ thẻ nhớ 512Gb', 'Li-Ion 4000 mAh', 'Copper,Black,Purple,Titan,Navy Blue', '1440 x 2960 pixels', '1 nano SIM']
# Link: https://clickbuy.com.vn/samsung-galaxy-note-9-liknew-ban-my-1-sim.html
# ******************************************************************************
# Liên kết: 197
# Tiêu đề sản phẩm: Samsung Galaxy S10 Plus 128GB Mỹ Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Tình trạng SP']
# Chi tiết: ['6.4 inches', 'Qualcomm Snapdragon 855', 'Android 9.0 (Pie)', '128 GB', '8 GB', '12 MP+12MP+16MP, LED Flash', '10 MP+8MP', 'Hỗ trợ thẻ nhớ 512Gb', 'Li-lon 4100 mAh', 'Black Ceramic,White Crystal,Navy Blue,Flamingo Pink', '1440 x 3040 pixels', '1 nano SIM', 'Quick Charge 2.0', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s10-plus-128gb-my-99.html
# ******************************************************************************
# Liên kết: 198
# Tiêu đề sản phẩm: Samsung Galaxy A73 8GB 128GB Chính Hãng Cũ
# Giá cũ: 3.290.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Sạc nhanh', 'Phụ kiện đi kèm']
# Chi tiết: ['6.7 inches', 'Snapdragon 778G 5G 8 nhân', 'Android 12, One UI 4.1', '128GB', '8Gb', 'Camera chính: 108 MP, f/1.8, PDAF, OIS Camera gó siêu rộng: 12 MP, f/2.2 Camera macro: 5 MP, f/2.4 Camera chân dung: 5 MP, f/2.4', '32 MP, f/2.2', '5000 mAh', 'Black,Blue,White', 'Super AMOLED, 6.7", Full HD+', '2 SIM (Nano-SIM)', 'Sạc nhanh 25W', 'Cáp Type C']
# Link: https://clickbuy.com.vn/samsung-galaxy-a73-8gb-128gb-chinh-hang-cu.html
# ******************************************************************************
# Liên kết: 199
# Tiêu đề sản phẩm: Samsung S20 Ultra (5G) 12GB 256GB Hàn Cũ
# Giá cũ: Liên hệ
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Màu sắc', 'Độ phân giải màn hình', 'Tình trạng SP']
# Chi tiết: ['6.9 inches', 'Exynos 990', 'Android 10, upgradable to Android 11, One UI 3.0', '256 GB', '12 GB', '108MP + 48MP + 12MP', '40MP', 'Black,Gray', '1440 x 3200 pixels', 'used']
# Link: https://clickbuy.com.vn/samsung-s20-ultra-5g-12gb-256gb-han-cu-99.html
# ******************************************************************************
# Liên kết: 200
# Tiêu đề sản phẩm: iPad 4 16GB 4G + Wifi 99%
# Giá cũ: 2.590.000 ₫
# Giá mới: 2.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Màu sắc', 'Độ phân giải màn hình', 'Thương hiệu', 'Tình trạng máy', 'Quay Phim']
# Chi tiết: ['9.7 inches', 'Apple A6X', '16GB', '1 GB', '5 MP', 'Black,White', '1536 x 2048 pixels', 'Apple', 'Đã qua sử dụng', 'Full HD 1080p (1920 x 1080 pixels)']
# Link: https://clickbuy.com.vn/ipad-4-16gb-4g-wifi.html
# ******************************************************************************
# Liên kết: 201
# Tiêu đề sản phẩm: Samsung Galaxy S21 (5G) 8GB 256GB cũ đẹp 99%
# Giá cũ: 6.290.000 ₫
# Giá mới: 6.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Sạc nhanh', 'Tình trạng SP']
# Chi tiết: ['6.2 inches', 'Exynos 2100 (5nm)', 'OneUI 3.1', '256 GB', '8 GB', 'Triple Camera (64MP + 12MP + 12MP)', '10MP (ToF)', 'microSDXC', 'Li-Po 4000mAH', 'Black,Silver,Violet', 'Full HD+ (1080 x 2400 Pixels)', 'Sạc nhanh 25W', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s21-256gb-cu.html
# ******************************************************************************
# Liên kết: 202
# Tiêu đề sản phẩm: Samsung Galaxy S21 Ultra (5G) 12GB 256GB cũ đẹp 99%
# Giá cũ: 8.590.000 ₫
# Giá mới: Liên hệ
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim', 'Tình trạng SP']
# Chi tiết: ['6.8 inches', 'Exynos 2100 (5nm)', 'Android 11, One UI 3.1', '256 GB', '12 GB', '108 MP, 12MP và 10MP+ 10MP+ 0.3 MP', '40MP', '5.000 mAh', 'Black,Copper,Silver', '2 nano SIM', 'used']
# Link: https://clickbuy.com.vn/samsung-galaxy-s21-ultra-256gb-han-cu-99.html
# ******************************************************************************
# Liên kết: 203
# Tiêu đề sản phẩm: Samsung Galaxy S21 Ultra (5G) 12GB 512GB Cũ đẹp 99%
# Giá cũ: 9.490.000 ₫
# Giá mới: 10.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim']
# Chi tiết: ['6.8 inches', 'Exynos 2100 (5nm)', 'Android 11, One UI 3.1', '512GB', '12 GB', '108 MP, 12MP và 10MP+ 10MP+ 0.3 MP', '40MP', '5.000 mAh', 'Black,Copper,Silver', '2 nano SIM']
# Link: https://clickbuy.com.vn/samsung-galaxy-s21-ultra-5g-12gb-512gb-my-cu-99.html
# ******************************************************************************
# Liên kết: 204
# Tiêu đề sản phẩm: Google Pixel 6 Pro 12GB 256GB cũ
# Giá cũ: 8.990.000 ₫
# Giá mới: 15.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Hệ điều hành', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Dung lượng pin', 'Màu sắc', 'Độ phân giải màn hình', 'Thẻ sim', 'Tình trạng SP', 'Thương hiệu sản phẩm']
# Chi tiết: ['6.71 inches', 'Google Tensor (5 nm)', 'Android 12', '256 GB', '12 GB', '50MP – 48MP – 12MP', '11.1 MP', '5000 mAh', 'Black,White,Orange', '1440 x 3120 pixels', '1 nano SIM + 1 eSIM', 'used', 'Google']
# Link: https://clickbuy.com.vn/google-pixel-6-pro-12gb-256gb-cu.html
# ******************************************************************************
# Liên kết: 205
# Tiêu đề sản phẩm: Điện thoại Sharp Aquos R6
# Giá cũ: 6.590.000 ₫
# Giá mới: 7.990.000 ₫
# Tiêu đề cấu hình: ['Kích thước màn hình', 'CPU', 'Bộ nhớ trong', 'RAM', 'Camera chính', 'Camera phụ', 'Thẻ nhớ', 'Dung lượng pin', 'Màu sắc', 'Thẻ sim']
# Chi tiết: ['6.67 inches', 'Snapdragon 888', '128 GB', '12 GB', '20 MP', '12 MP', 'Hỗ trợ thẻ nhớ 1TB', '5000 mAh', 'Black,Silver', '1 nano SIM']
# Link: https://clickbuy.com.vn/dien-thoai-sharp-aquos-r6.html
# ******************************************************************************

# %%
print(len(feature_names))
# Out:
# 47
